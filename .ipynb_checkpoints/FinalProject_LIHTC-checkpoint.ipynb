# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
import requests
from functools import partial
pd.options.mode.chained_assignment = None

import time

# %%
df = pd.read_csv("C:\Users\Dave\Desktop\Final Project\LIHTC_Properties_wGeocode.csv", low_memory=False)
df.head(10)
# Out:
#    FID  OBJECTID      HUD_ID                           PROJECT  \
# 0    0      5001  CAA2010235                 ROSA PARKS VILLAS
# 1    1      5002  CAA2011484                    CUATRO VIENTOS
# 2    2      5003  CAA2011485           VILLAGE AT BROAD STREET
# 3    3      5004  CAA2011486                      CYNARA COURT
# 4    4      5005  CAA2011490          TOUSSIN SENIOR APRTMENTS
# 5    5      5006  CAA2011492                   TREE HOUSE APTS
# 6    6      5007  CAA2011495                       TRESOR APTS
# 7    7      5008  CAA2012879                        LAS BRISAS
# 8    8      5009  CAA2012880  VINTAGE AT LAGUNA SENIOR APTS II
# 9    9      5010  CAA2012881           PRESIDIO EL CAMINO APTS
#
#                PROJ_ADD         PROJ_CTY PROJ_ST  PROJ_ZIP   STATE_ID  \
# 0    2507 S BRONSON AVE      LOS ANGELES      CA     90018  CA-07-009
# 1  5331 HUNTINGTON DR N      LOS ANGELES      CA     90032  CA-09-205
# 2         2260 EMILY ST  SAN LUIS OBISPO      CA     93401  CA-09-124
# 3      10868 MERRITT ST      CASTROVILLE      CA     95012  CA-10-818
# 4        10 TOUSSIN AVE        KENTFIELD      CA     94904  CA-09-198
# 5   488 W CHARLESTON RD        PALO ALTO      CA     94306  CA-10-025
# 6      1041 BUCKHORN DR          SALINAS      CA     93905  CA-09-233
# 7      2001 N EIGHTH ST        EL CENTRO      CA     92243  CA-11-843
# 8    9204 BIG HORN BLVD        ELK GROVE      CA     95758  CA-11-841
# 9   1490 EL CAMINO REAL      SANTA CLARA      CA     95050  CA-11-839
#
#                   CONTACT  ...   STM2KX LVL2KX UR                      MSG2KX  \
# 0         J DUPONT-WALKER  ...               R  U  ** Street-Level Rooftop **
# 1  JACQUELINE MONTERROSAS  ...               R  U  ** Street-Level Rooftop **
# 2          JONATHAN EMAMI  ...               R  U  ** Street-Level Rooftop **
# 3        MATTHEW FRANKLIN  ...               R  U  ** Street-Level Rooftop **
# 4             MARY STOMPE  ...               R  U  ** Street-Level Rooftop **
# 5        CANDICE GONZALEZ  ...               R  U  ** Street-Level Rooftop **
# 6             CALEB ROOPE  ...               R  U  ** Street-Level Rooftop **
# 7            LARRY CORTES  ...               R  U  ** Street-Level Rooftop **
# 8       KENNETH ROBERTSON  ...               R  U  ** Street-Level Rooftop **
# 9             CHRIS NEALE  ...               R  U  ** Street-Level Rooftop **
#
#   COUNTY_LEV PLACE_LEVE  TRACT_LEVE   BLKGRP_LEV   MSA   CBSA
# 0       6037    0644000  6037218702  60372187021  4480  31084
# 1       6037    0644000  6037201120  60372011201  4480  31084
# 2       6079    0668154  6079011102  60790111024  7460  42020
# 3       6053    0611978  6053010400  60530104002  7120  41500
# 4       6041    0638114  6041119100  60411191002  7360  42034
# 5       6085    0655282  6085510700  60855107003  7400  41940
# 6       6053    0664224  6053010605  60530106051  7120  41500
# 7       6025    0621782  6025011201  60250112012  9999  20940
# 8       6067    0622020  6067009639  60670096393  6920  40900
# 9       6085    0669084  6085505600  60855056001  7400  41940
#
# [10 rows x 130 columns]

# %%
list(df)
# Out:
# ['FID',
#  'OBJECTID',
#  'HUD_ID',
#  'PROJECT',
#  'PROJ_ADD',
#  'PROJ_CTY',
#  'PROJ_ST',
#  'PROJ_ZIP',
#  'STATE_ID',
#  'CONTACT',
#  'COMPANY',
#  'CO_ADD',
#  'CO_CTY',
#  'CO_ST',
#  'CO_ZIP',
#  'CO_TEL',
#  'ALLOCAMT',
#  'N_UNITS',
#  'LI_UNITS',
#  'N_0BR',
#  'N_1BR',
#  'N_2BR',
#  'N_3BR',
#  'N_4BR',
#  'INC_CEIL',
#  'LOW_CEIL',
#  'CEILUNIT',
#  'YR_PIS',
#  'YR_ALLOC',
#  'NON_PROF',
#  'BASIS',
#  'BOND',
#  'MFF_RA',
#  'MFF_RA_ID',
#  'FMHA_514',
#  'RDNUM_514',
#  'FMHA_515',
#  'RDNUM_515',
#  'FMHA_538',
#  'RDNUM_538',
#  'HOME',
#  'HOME_AMT',
#  'HOME_IDISI',
#  'TCAP',
#  'TCAP_AMT',
#  'TCAP_IDISI',
#  'CDBG',
#  'CDBG_AMT',
#  'CDBG_IDISI',
#  'FHA',
#  'FHA_NUM',
#  'HOPEVI',
#  'HPVI_AMT',
#  'TCEP',
#  'TCEP_AMT',
#  'RENTASSIST',
#  'TRGT_POP',
#  'TRGT_FAM',
#  'TRGT_ELD',
#  'TRGT_DIS',
#  'TRGT_HML',
#  'TRGT_OTHER',
#  'TRGT_SPC',
#  'TYPE',
#  'CREDIT',
#  'N_UNITSR',
#  'LI_UNITR',
#  'DDA',
#  'QCT',
#  'NONPROG',
#  'DATANOTE',
#  'METRO_TRAC',
#  'STATE2KX',
#  'CNTY_NM2KX',
#  'CNTY2KX',
#  'TRACT2KX',
#  'BG2KX',
#  'BLOCK2KX',
#  'CURCNTY_NM',
#  'CURCNTY',
#  'CURCOSUB',
#  'CURCOSUB_N',
#  'PLACE2KX',
#  'PLACE_NM2K',
#  'PLACE_CC2K',
#  'PLACE_INC2',
#  'MSA_NM',
#  'CBSA_NM',
#  'NECTA',
#  'NECTA_NM',
#  'METRO',
#  'MICRO',
#  'FCD_FIPS91',
#  'HLC',
#  'DPV',
#  'DPVRC',
#  'STD_ADDR',
#  'URB_OUT',
#  'STD_CITY',
#  'STD_ST',
#  'STD_ZIP5',
#  'STD_ZIP9',
#  'ZIP_CLASS',
#  'ZCTA2KX',
#  'DPBC',
#  'DPBC_CKSUM',
#  'STD_ZIP11',
#  'ADDR_TYPE',
#  'APT_NO',
#  'APT_TYPE',
#  'C1PGRC',
#  'C1PPRB',
#  'C1PDRC',
#  'C1PSRC',
#  'C1PARC',
#  'C1PRC9',
#  'MSGUSPS',
#  'LAT',
#  'LON',
#  'RC2KX',
#  'STM2KX',
#  'LVL2KX',
#  'UR',
#  'MSG2KX',
#  'COUNTY_LEV',
#  'PLACE_LEVE',
#  'TRACT_LEVE',
#  'BLKGRP_LEV',
#  'MSA',
#  'CBSA']

# %%
#properties by states
df_groupby = df.groupby('YR_PIS').count()
df_groupby = df_groupby[['FID']]
df_groupby
#add visualization of placed in service date
#add visualization of increases in rent!
#add viz of number of units, number of bedrroms
#add visualization of target families, homeless, disabled
#add viz of covarites
#use python.strip to get rid of bad data
# Out:
#          FID
# YR_PIS
# 1987     662
# 1988    1480
# 1989    1412
# 1990    1127
# 1991    1216
# 1992    1139
# 1993    1232
# 1994    1253
# 1995    1426
# 1996    1317
# 1997    1262
# 1998    1265
# 1999    1489
# 2000    1315
# 2001    1393
# 2002    1330
# 2003    1500
# 2004    1523
# 2005    1560
# 2006    1538
# 2007    1539
# 2008    1304
# 2009    1055
# 2010    1025
# 2011    1328
# 2012    1136
# 2013     928
# 2014     558
# 2015      43
# 8888    2943
# 9999      67

# %%
#webscrap from the census bureau American FactFinder
mytoken = "9bd9fa373d767eaa91be6a4c2643abbd38f3049e"
def ACS_data(year,census_id, tract,state,county):
    time.sleep(.3)
    url = 'http://api.census.gov/data/' + str(year) + '/acs5?get=' + census_id + '&for=tract:' + str(tract) + '&in=state:' + str(state) + '+county:'+ str(county) + '&key=' + mytoken
    response = requests.get(url)
    #returns the median income we want!
    return response.json()[1][0]
    #print type(response.json())

# %%
df_tiny = df.head(50)
df_tiny['MHI_2010'] = df_tiny.apply(lambda x: ACS_data('2010','B06011_001E',x['TRACT2KX'], x['STATE2KX'],x['CNTY2KX']), axis=1)
df_tiny['MHI_2011'] = df_tiny.apply(lambda x: ACS_data('2011','B06011_001E',x['TRACT2KX'], x['STATE2KX'],x['CNTY2KX']), axis=1)
df_tiny['MHI_2012'] = df_tiny.apply(lambda x: ACS_data('2012','B06011_001E',x['TRACT2KX'], x['STATE2KX'],x['CNTY2KX']), axis=1)
df_tiny['MHI_2013'] = df_tiny.apply(lambda x: ACS_data('2013','B06011_001E',x['TRACT2KX'], x['STATE2KX'],x['CNTY2KX']), axis=1)
df_tiny['MHI_2014'] = df_tiny.apply(lambda x: ACS_data('2014','B06011_001E',x['TRACT2KX'], x['STATE2KX'],x['CNTY2KX']), axis=1)
df_tiny['MHI_2015'] = df_tiny.apply(lambda x: ACS_data('2015','B06011_001E',x['TRACT2KX'], x['STATE2KX'],x['CNTY2KX']), axis=1)

# %%
df_tiny
# Out:
#     FID  OBJECTID      HUD_ID                                  PROJECT  \
# 0     0      5001  CAA2010235                        ROSA PARKS VILLAS
# 1     1      5002  CAA2011484                           CUATRO VIENTOS
# 2     2      5003  CAA2011485                  VILLAGE AT BROAD STREET
# 3     3      5004  CAA2011486                             CYNARA COURT
# 4     4      5005  CAA2011490                 TOUSSIN SENIOR APRTMENTS
# 5     5      5006  CAA2011492                          TREE HOUSE APTS
# 6     6      5007  CAA2011495                              TRESOR APTS
# 7     7      5008  CAA2012879                               LAS BRISAS
# 8     8      5009  CAA2012880         VINTAGE AT LAGUNA SENIOR APTS II
# 9     9      5010  CAA2012881                  PRESIDIO EL CAMINO APTS
# 10   10      5011  CAA2012882                       VINTAGE CHATEAU II
# 11   11      5012  CAA2012883                  AMANDA PARK SENIOR APTS
# 12   12      5013  CAA2012884                           ORANGE GARDENS
# 13   13      5014  CAA2012885                          HIGH PLACE WEST
# 14   14      5015  CAA2013021                          DAHLIA COURT II
# 15   15      5016  CAA2013022            DEL REY SQUARE SENIOR HOUSING
# 16   16      5017  CAA2013023                        DESCANSO PLACE II
# 17   17      5018  CAA2013024                        DESCANSO PLACE IV
# 18   18      5019  CAA2013025                      DESERT MEADOWS APTS
# 19   19      5020  CAA2013026                       DINUBA SENIOR APTS
# 20   20      5021  CAA2013027                       DRASNIN MANOR APTS
# 21   21      5022  CAA2010806                        SPRINGBROOK GROVE
# 22   22      5023  CAA2010807                     GLENDALE CITY LIGHTS
# 23   23      5024  CAA2011003                        15TH & COMMERCIAL
# 24   24      5025  CAA2011005                          ALMONDWOOD APTS
# 25   25      5026  CAA2011010                        AMOROSA VILLAGE I
# 26   26      5027  CAA2011015                       AMOROSA VILLAGE II
# 27   27      5028  CAA2011020                  APARICIO COMMUNITY APTS
# 28   28      5029  CAA2011510                VALLEY OAKS APTS PHASE II
# 29   29      5030  CAA2011515              VALLEY VISTA SENIOR HOUSING
# 30   30      5031  CAA2011520                      VARENNA SENIOR APTS
# 31   31      5032  CAA2011522                       VENDOME PALMS APTS
# 32   32      5033  CAA2011525                      VERBENA FAMILY APTS
# 33   33      5034  CAA2011530                         VILLA SIENA APTS
# 34   34      5035  CAA2011535                               VILLAGE II
# 35   35      5036  CAA2012950                     SHERMAN VILLAGE APTS
# 36   36      5037  CAA2012951                     SOUTH STREET ANAHEIM
# 37   37      5038  CAA2012952                           FOOTHILL FARMS
# 38   38      5039  CAA2012953                             7TH & H APTS
# 39   39      5040  CAA2012954                 COMMUNITY OF ALL NATIONS
# 40   40      5041  CAA2012955                            POTTERY COURT
# 41   41      5042  CAA2012956                       BECKES STREET APTS
# 42   42      5043  CAA2012850                             MONO HILLTOP
# 43   43      5044  CAA2012851                   CROSSING AT NORTH LOOP
# 44   44      5045  CAA2012852                                PALMDALIA
# 45   45      5046  CAA2012853                       CALIFORNIA TERRACE
# 46   46      5047  CAA2012854  KC CONSOLIDATED BEAR MOUNTAIN WEEDPATCH
# 47   47      5048  CAA2012855                 POSO MANOR & ROSE VALLEY
# 48   48      5049  CAA2012856                          DE ANZA APTS II
# 49   49      5050  COA1999090                             MESA GARDENS
#
#                        PROJ_ADD         PROJ_CTY PROJ_ST  PROJ_ZIP   STATE_ID  \
# 0            2507 S BRONSON AVE      LOS ANGELES      CA     90018  CA-07-009
# 1          5331 HUNTINGTON DR N      LOS ANGELES      CA     90032  CA-09-205
# 2                 2260 EMILY ST  SAN LUIS OBISPO      CA     93401  CA-09-124
# 3              10868 MERRITT ST      CASTROVILLE      CA     95012  CA-10-818
# 4                10 TOUSSIN AVE        KENTFIELD      CA     94904  CA-09-198
# 5           488 W CHARLESTON RD        PALO ALTO      CA     94306  CA-10-025
# 6              1041 BUCKHORN DR          SALINAS      CA     93905  CA-09-233
# 7              2001 N EIGHTH ST        EL CENTRO      CA     92243  CA-11-843
# 8            9204 BIG HORN BLVD        ELK GROVE      CA     95758  CA-11-841
# 9           1490 EL CAMINO REAL      SANTA CLARA      CA     95050  CA-11-839
# 10          325 N MCDOWELL BLVD         PETALUMA      CA     94954  CA-11-837
# 11       24425 SKYVIEW RIDGE DR         MURRIETA      CA     92562  CA-11-836
# 12           12510 OAK KNOLL RD            POWAY      CA     92064  CA-11-835
# 13            2345 VIRGINIA AVE     SANTA MONICA      CA     90404  CA-11-834
# 14               1305 DAHLIA CT      CARPINTERIA      CA     93013  CA-11-107
# 15            11976 CULVER BLVD      LOS ANGELES      CA     90066  CA-11-811
# 16              716 DESCANSO ST      BAKERSFIELD      CA     93306  CA-12-071
# 17             823 REMBRANDT ST      BAKERSFIELD      CA     93306  CA-12-177
# 18             44071 CLINTON ST            INDIO      CA     92201  CA-11-830
# 19                   350 N M ST           DINUBA      CA     93618  CA-11-157
# 20      2530 INTERNATIONAL BLVD          OAKLAND      CA     94601  CA-11-929
# 21               435 ALTURAS RD        FALLBROOK      CA     92028  CA-08-825
# 22         3673 SAN FERNANDO RD         GLENDALE      CA     91204  CA-07-148
# 23            1501 IMPERIAL AVE        SAN DIEGO      CA     92101  CA-09-606
# 24                801 DUTTON ST          WINTERS      CA     95694  CA-09-601
# 25          1300 PEBBLECREEK DR       SANTA ROSA      CA     95407  CA-09-527
# 26          1300 PEBBLECREEK DR       SANTA ROSA      CA     95407  CA-09-012
# 27         332 ELLWOOD BEACH DR           GOLETA      CA     93117  CA-10-502
# 28                   351 N W ST           TULARE      CA     93274  CA-09-513
# 29  20503 SAN RAMON VALLEY BLVD        SAN RAMON      CA     94583  CA-09-549
# 30                2351 WYDA WAY       SACRAMENTO      CA     95825  CA-09-073
# 31             975 N VENDOME ST      LOS ANGELES      CA     90026  CA-10-800
# 32              3774 BEYER BLVD       SAN YSIDRO      CA     92173  CA-09-032
# 33                   200 N E ST      PORTERVILLE      CA     93257  CA-09-163
# 34           506 CIVIC CTR BLVD      SUISUN CITY      CA     94585  CA-10-827
# 35              7135 WILBUR AVE           RESEDA      CA     91335  CA-10-227
# 36                   712 E S ST          ANAHEIM      CA     92805  CA-10-210
# 37             5400 AUBURN BLVD       SACRAMENTO      CA     95841  CA-10-202
# 38               720 SEVENTH ST       SACRAMENTO      CA     95814  CA-10-175
# 39              2172 DOCKERY CT         STOCKTON      CA     95206  CA-10-171
# 40             295 W SUMNER AVE    LAKE ELSINORE      CA     92530  CA-10-158
# 41              2650 SPRUCE AVE            WASCO      CA     93280  CA-10-148
# 42                  757 MONO ST           FRESNO      CA     93706  CA-11-924
# 43             3930 TARMIGAN DR         ANTELOPE      CA     95843  CA-11-922
# 44              38028 11TH ST E         PALMDALE      CA     93550  CA-11-916
# 45          21501 LAKE SHORE DR  CALIFORNIA CITY      CA     93505  CA-11-914
# 46                128 MONROE ST            ARVIN      CA     93203  CA-11-913
# 47              1840 POPLAR AVE            WASCO      CA     93280  CA-11-912
# 48             444 ROCKWOOD AVE         CALEXICO      CA     92231  CA-11-906
# 49               2207 E 12TH ST           PUEBLO      CO     81001     980048
#
#                    CONTACT    ...     TRACT_LEVE   BLKGRP_LEV   MSA   CBSA  \
# 0          J DUPONT-WALKER    ...     6037218702  60372187021  4480  31084
# 1   JACQUELINE MONTERROSAS    ...     6037201120  60372011201  4480  31084
# 2           JONATHAN EMAMI    ...     6079011102  60790111024  7460  42020
# 3         MATTHEW FRANKLIN    ...     6053010400  60530104002  7120  41500
# 4              MARY STOMPE    ...     6041119100  60411191002  7360  42034
# 5         CANDICE GONZALEZ    ...     6085510700  60855107003  7400  41940
# 6              CALEB ROOPE    ...     6053010605  60530106051  7120  41500
# 7             LARRY CORTES    ...     6025011201  60250112012  9999  20940
# 8        KENNETH ROBERTSON    ...     6067009639  60670096393  6920  40900
# 9              CHRIS NEALE    ...     6085505600  60855056001  7400  41940
# 10       KENNETH ROBERTSON    ...     6097150603  60971506031  7500  42220
# 11       KENNETH ROBERTSON    ...     6065043206  60650432063  6780  40140
# 12          DARRIN WILLARD    ...     6073017048  60730170481  7320  41740
# 13         DURINDA ABRAHAM    ...     6037701801  60377018014  4480  31084
# 14             MARK WILSON    ...     6083001601  60830016012  7480  42200
# 15            ANDREW GROSS    ...     6037275500  60372755001  4480  31084
# 16            LORI KOESTER    ...     6029001103  60290011032   680  12540
# 17            LORI KOESTER    ...     6029001103  60290011032   680  12540
# 18            TRACY THOMAS    ...     6065045217  60650452171  6780  40140
# 19            LARRY CORTES    ...     6107000501  61070005014  8780  47300
# 20            JOSHUA SIMON    ...     6001406201  60014062014  5775  36084
# 21              JOHN DOYLE    ...     6073018904  60730189041  7320  41740
# 22              ELVA GRANT    ...     6037302505  60373025053  4480  31084
# 23            DIANE STUMPH    ...     6073005100  60730051002  7320  41740
# 24          MICHAEL CONDRY    ...     6113011300  61130113001  9270  40900
# 25          TOM LAUDERBACH    ...     6097153200  60971532004  7500  42220
# 26              JOHN LOWRY    ...     6097153200  60971532004  7500  42220
# 27            BOB HAVLICEK    ...     6083002930  60830029306  7480  42200
# 28         JOSEPH MICHAELS    ...     6107002202  61070022023  8780  47300
# 29             DAVE KIDDOO    ...     6013345115  60133451151  5775  36084
# 30              MARK WIESE    ...     6067005505  60670055053  6920  40900
# 31        DORA LEONG GALLO    ...     6037195803  60371958031  4480  31084
# 32           CHERI HOFFMAN    ...     6073010005  60730100053  7320  41740
# 33              ELVA GRANT    ...     6107003802  61070038022  8780  47300
# 34         GAIL ZICK CLYDE    ...     6095252702  60952527023  8720  46700
# 35         LEANNE TRUOFREH    ...     6037132501  60371325011  4480  31084
# 36           JONATHAN WEBB    ...     6059086301  60590863013  5945  11244
# 37           SUSAN JOHNSON    ...     6067007501  60670075012  6920  40900
# 38      WENDY SACA-MERTENS    ...     6067005301  60670053011  6920  40900
# 39           CAROL ORNELAS    ...     6077002100  60770021001  8120  44700
# 40           SUSAN JOHNSON    ...     6065043006  60650430062  6780  40140
# 41              PAT NEWMAN    ...     6029004401  60290044013   680  12540
# 42          PATRICK HARPER    ...     6019000300  60190003003  2840  23420
# 43         CHRISTINA ALLEY    ...     6067007430  60670074303  6920  40900
# 44             ERIN CAPUTO    ...     6037910501  60379105013  4480  31084
# 45     KIMBERLEY MCCLINTON    ...     6029005507  60290055072   680  12540
# 46     KIMBERLEY MCCLINTON    ...     6029006303  60290063031   680  12540
# 47     KIMBERLEY MCCLINTON    ...     6029004301  60290043013   680  12540
# 48            LARRY CORTES    ...     6025012100  60250121003  9999  20940
# 49          CHARLES SINGER    ...     8101001000  81010010001  6560  39380
#
#    MHI_2010 MHI_2011  MHI_2012  MHI_2013  MHI_2014  MHI_2015
# 0     15307    15854     16068     15307     17582      None
# 1     20473    20343     18528     18129     18436     17846
# 2     25020    25643     25389     26461     29457      None
# 3     18902    19074     17210     17929     19341      None
# 4     44228    48438     48965     47802     56169      None
# 5     61181    62188     55966     50487     52097      None
# 6     19815    19735     20313     20906     21725      None
# 7     30916    32535     30417     30207     26000     24909
# 8     27324    25502     21716     21125     21894     20593
# 9     16132    11779     11180     10550      9435      None
# 10    25452    28365     25832     28392     30648     34342
# 11    29757    29010     24010     30490     31108      None
# 12    31274    30302     29871     31244     29892      None
# 13    30704    30984     29002     29312     28289     29252
# 14    34167    36408     38324     39357     35128     37304
# 15    17000    16600     17128     14948     17511     18384
# 16    14382    14302     13156     13958     13518     13179
# 17    14382    14302     13156     13958     13518     13179
# 18    21270    20565     17751     18561     17124     20009
# 19    14867    14232     13372     13957     14727     15000
# 20    16112    16891     16367     14787     15202      None
# 21    25980    24874     25735     26970     22243      None
# 22    15203    14972     14916     15836     14725      None
# 23    16533    15229     15694     15497     16035     17137
# 24    25192    25523     29566     26653     27441     30714
# 25    26243    27397     24506     25283     25748      None
# 26    26243    27397     24506     25283     25748      None
# 27    29256    32609     31091     35874     36436      None
# 28    16235    16266     14544     14916     14993     14713
# 29    68750    73015     64005     62855     63526     61283
# 30    25589    23771     21878     20709     21267     21640
# 31    22035    30545     38769     32930     27925     30670
# 32    15826    17046     16580     16482     14694     14277
# 33    13892    13361     13134     12869     12041     11865
# 34    33801    35575     35333     35637     36648      None
# 35    22870    19012     19264     20035     19795     19215
# 36    19968    20439     20839     19823     22032      None
# 37    24741    21676     21372     21289     20393     20490
# 38     9575     7969      8341      8797      8993      9494
# 39    14701    15492     13446     14375     15743     15703
# 40    19471    21768     18689     17700     17212     19435
# 41    19347    20292     19645     18272     18261     17682
# 42    12667    13857     16607     12615     14885     14647
# 43    31375    32011     30517     29011     28795      None
# 44    14749    13948     14080     12697     11741     11994
# 45    21499    22496     25774     25073     30268     28240
# 46    12871    13945     15589     15207     14438      None
# 47    17400    17584     17943     17525     16830     16893
# 48    11547    11346     10960     10826     10993      None
# 49    12728    13782     13152     14035     14715     15725
#
# [50 rows x 136 columns]
