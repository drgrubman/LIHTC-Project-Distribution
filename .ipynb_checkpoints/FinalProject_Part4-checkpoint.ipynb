# %% [markdown]
# ## Final Project Part 4
# #### David Grubman
# Yeah, I stole that sweet get_linear_model_metrics (among other stole lines of code) Thanks for these!
#
# There is a few remaining data clean up items that needed to happen and I wanted to make sure I showed you.

# %%
#import libraries!
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
import requests

pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', None)

# %matplotlib inline

import time
from sklearn import linear_model, metrics, model_selection, feature_selection, cross_validation



def get_linear_model_metrics(X, y, algo):
    # get the pvalue of X given y. Ignore f-stat for now.
    pvals = feature_selection.f_regression(X, y)[1]
    # start with an empty linear regression object
    # .fit() runs the linear regression function on X and y
    algo.fit(X,y)
    residuals = (y-algo.predict(X)).values

    # print the necessary values
    print 'P Values:', pvals
    print 'Coefficients:', algo.coef_
    print 'y-intercept:', algo.intercept_
    print 'R-Squared:', algo.score(X,y)
    plt.figure()
    plt.hist(residuals)
    # keep the model
    return algo
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#Import df_tiny ()
df_tiny = pd.read_csv("LIHTC_Properties_wGeocode_Census.csv",low_memory=False)

# %% [markdown]
# ### Add a column that compares each census tract income to it's state median income.
# #### Yes, it's a little more data cleanup and API running but it makes the analysis more compelling and adds a new set of potential predictor variables variables. This was done in a seperate notebook and saved to a csv.

# %%
#import the state dataset (the same API as before was run on this in a seperate notebook, then saved to a CSV)
df_states = pd.read_csv("States_with_Income.csv",low_memory=False)
df_states['PROJ_ST'] = df_states['Abbrev']
df_states['Code'] = df_states['Code'].astype(str).str.strip().astype(int)
df_states['StateCode'] = df_states.Code.map("{:02}".format)
print len(df_states)
df_states.head(10)
# Out:
# 51
#    Unnamed: 0  Code  State Code                 State       Abbrev  ID_Code  \
# 0           0     1           1               Alabama   AL                1
# 1           1     2           2                Alaska  AK                 2
# 2           2     4           4               Arizona   AZ                4
# 3           3     5           5              Arkansas    AR               5
# 4           4     6           6            California      CA             6
# 5           5     8           8              Colorado    CO               8
# 6           6     9           9           Connecticut       CT            9
# 7           7    10          10              Delaware    DE              10
# 8           8    11          11  District of Columbia     DC             11
# 9           9    12          12               Florida   FL               12
#
#    MHI_2010  MHI_2011  MHI_2012  MHI_2013  MHI_2014  MHI_2015  10_14_Growth  \
# ...

# %% [markdown]
# ### Refine the data set and create dummy variables, as well as other calculations
# #### We're predicting the ACS Median Income in 2014....NOT the percent change as originally thought.
#
# There is still some data cleanup to be done - especially since I wasn't able to determine the variables used in the Linear Regression until I could see some R-squareds and MSE's.
#
# This was also where I could go back substitute, refine, and add additional variables to my model.
#
#
# #### My Final Predictor Variables
#
# -Income in 2010 (based on the American Community Survey)
#
# -Number of Low-Income units added to the Census Tract
#
# -Difficult Development Area (areas that have high construction costs)
#
# -Targeted Population (1 indicated if it's a elderly/homeless/disable project, 0 indicates if it's a general family property)
#
# Note: I had tested a regression using a comparison against the states' median income - i.e. is this census tract above or below the state median income? This would indicate that a project was placed in a rich neighborhood. However, that was found to be very collinear to Income in 2010.

# %%
df_tiny =  df_tiny[(df_tiny.YR_PIS == 2006)|(df_tiny.YR_PIS == 2007)|(df_tiny.YR_PIS == 2008)|(df_tiny.YR_PIS == 2009)|(df_tiny.YR_PIS == 2010) | (df_tiny.YR_PIS == 2011)|(df_tiny.YR_PIS == 2012)|(df_tiny.YR_PIS == 2013)|(df_tiny.YR_PIS == 2014)|(df_tiny.YR_PIS == 2015)]
#df_tiny =  df_tiny[(df_tiny.YR_PIS == 2006)]
df_tiny = df_tiny[np.isfinite(df_tiny['MHI_2014'])]
df_tiny = df_tiny[np.isfinite(df_tiny['MHI_2010'])]
df_tiny = df_tiny[np.isfinite(df_tiny['HH_2010'])]
df_tiny = df_tiny[np.isfinite(df_tiny['N_UNITS'])]
df_tiny = df_tiny[np.isfinite(df_tiny['LI_UNITS'])]

#creating income growth 
df_tiny['10_14_Growth'] = df_tiny['MHI_2014'].astype(int) - df_tiny['MHI_2010'].astype(int)
df_tiny['PercentGrowth'] = (df_tiny['MHI_2014'].astype(int) - df_tiny['MHI_2010'].astype(int)) / df_tiny['MHI_2010'].astype(int)


df_tiny['Code'] = df_tiny['STATE2KX'].astype(str).str.strip().astype(int)
df_tiny['StateCode'] = df_tiny.Code.map("{:02}".format)
df_tiny['N_UNITS'] = df_tiny['N_UNITS'].astype(float)
df_tiny['TRGT_FAM'] = df_tiny['TRGT_FAM'].astype(int)

print "unique values in  target family: " + str(df_tiny.TRGT_FAM.unique())
print "unique values in type: " + str(df_tiny.TYPE.unique())


#append state household data to each row (so we can see how this census tract compared to the entire state)

df_tiny = df_tiny.merge(df_states, on='StateCode',indicator=True)
df_tiny['IncomeLevel'] = df_tiny['MHI_2010_x'] / df_tiny['MHI_2010_y']

#create qct, family, dummy and other dummy variables
df_tiny= pd.get_dummies(df_tiny, prefix='TargetPop', columns=['TRGT_FAM'])
df_tiny= pd.get_dummies(df_tiny, prefix='ConsType', columns=['TYPE'])
df_tiny= pd.get_dummies(df_tiny, prefix='Metro', columns=['METRO'])
df_tiny= pd.get_dummies(df_tiny, prefix='DDA', columns=['DDA'])
df_tiny= pd.get_dummies(df_tiny, prefix='QCT', columns=['QCT'])
# Out:
# unique values in  target family: [2 1 0]
# unique values in type: [1 3 2 0]

# %%
#create distribution of income percentages
sns.distplot(df_tiny['IncomeLevel'], kde=False, rug=True,bins=50)
df_tiny['IncomeLevel'].describe()
# Out:
# count    10434.000000
# mean         0.848622
# std          0.335148
# min          0.121152
# 25%          0.620171
# 50%          0.794941
# 75%          1.008118
# max          4.653381
# Name: IncomeLevel, dtype: float64

# %%
# Any census tract with income at or above its state median income can be considered "high income".

#I've noted it with the category "income threshold" below. This would put it in the 75th percentile and above for all Census Tracts
# with LIHTC projects
df_tiny['IncomeThresh'] = 0
df_tiny.loc[df_tiny.IncomeLevel > 1, 'IncomeThresh'] = 1

#I ended up not using this!

# %%
#remove outliers in the data set
#50% growth rate is probably unrealistic and is a data error in the ACS Median Income data.
df_tiny = df_tiny[(df_tiny.PercentGrowth_x < .5)]

# %% [markdown]
# ### Aggregate census tracts with multiple properties on them to sum the total numbers of units.

# %%
#group by census tract. use this to sum the total number of units in a single census tract (so we don't repeat)
df_group = df_tiny.groupby('TRACT_LEVE').agg(sum)
df_group = df_group.reset_index()
df_group = df_group[['TRACT_LEVE','N_UNITS','LI_UNITS']]

#now do a merge based on df_tiny
df = pd.merge(df_tiny, df_group, on='TRACT_LEVE', how='inner')

# %% [markdown]
# #### One last correlation to see if any collinearity before I train the model.

# %%
corr = df[['MHI_2010_x','LI_UNITS_x','TargetPop_1','DDA_1','IncomeThresh']].corr()
sns.heatmap(corr)
corr
# Out:
#               MHI_2010_x  LI_UNITS_x  TargetPop_1     DDA_1  IncomeThresh
# MHI_2010_x      1.000000    0.006646    -0.022462  0.022688      0.730658
# LI_UNITS_x      0.006646    1.000000     0.072068  0.124302      0.015313
# TargetPop_1    -0.022462    0.072068     1.000000  0.010054     -0.025927
# DDA_1           0.022688    0.124302     0.010054  1.000000     -0.048675
# IncomeThresh    0.730658    0.015313    -0.025927 -0.048675      1.000000

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Run the model
# I thought an SGD regressor would have been better but it turns out linear_model.Linear Regression works very quickly and is probably more accurate.
#
# Linear regression is simple. I at first thought I'd have to add polynomials or log tranform my data, but it turns out I didn't have to due to my R-squred value being so high.
#
# The get_linear_metrics gives me a lot of good data, including MSEs and P-values.

# %%
#here we go!
X = df[['MHI_2010_x','LI_UNITS_x','TargetPop_1','DDA_1']]
#'IncomeThresh' I decided to throw away the comparison to the state Income due to colilnearity above. 
y = df['MHI_2014_x']



#i could square the variables for a polynomial fit. or log transform. doesn't seem neccessary.

#lm = linear_model.SGDRegressor(random_state=4)  #Try SGD to see if it works with a constant random state.
lm = linear_model.LinearRegression()
lm.fit(X, y)

print "~~~~Linear Model Metrics~~~~~"
lm = get_linear_model_metrics(X, y, lm)
print 'MSE', metrics.mean_squared_error(y, lm.predict(X))
# Out:
# ~~~~Linear Model Metrics~~~~~
# P Values: [ 0.          0.40916979  0.05365917  0.20943458]
# Coefficients: [   0.96592574   -1.70825366   57.12010828 -180.70513562]
# y-intercept: 1427.14184909
# R-Squared: 0.865103832571
# MSE 12601714.4227

# %% [markdown]
# #### Visualize predicted values

# %%
X = df[['MHI_2010_x','LI_UNITS_x','TargetPop_1','DDA_1']]
df['Prediction'] = lm.predict(X)
ax = sns.regplot(x="Prediction", y="MHI_2014_x", data=df, ci=95)

# %%
ax = sns.regplot(x="LI_UNITS_x", y="Prediction", data=df, ci=95)

# %%
#### Plotting with my best two variables - Median Income in 2010 and "Targeted Population" This isn't great but provides some picture.
lm_fig  = sns.lmplot(x="MHI_2010_x", y="MHI_2014_x", order=1, data=df, hue='TargetPop_1')
axes = lm_fig.axes
#axes[0,0].set_ylim(-0.75,.6)
#axes[0,0].set_xlim(0,700)
sns.plt.title('Overall')
lm_fig.savefig('pictures/Overall.png')

# %% [markdown]
# #### Plotting residuals.
# The don't look too bad!  The residuals appear to be normally distributed.

# %%
resids = y - lm.predict(X)
residplt = sns.distplot(resids)

# %% [markdown]
# #### Lasso and Ridge
# Lasso and ridge wont solve high bias, will only help for variance.
# My R-squareds are actually pretty good so I don't know if these will help. But it was worth running these anyway

# %%
lm = linear_model.Lasso().fit(X, y)
print "~~~ Lasso ~~~"
print 'Lasso MSE: ', metrics.mean_squared_error(y, lm.predict(X))
print 'Lasso R2:', lm.score(X, y)


lm = linear_model.Ridge().fit(X, y)
print "~~~ Ridge ~~~"
print 'Ridge MSE: ', metrics.mean_squared_error(y, lm.predict(X))
print 'Ridge R2:', lm.score(X, y)
# Out:
# ~~~ Lasso ~~~
# Lasso MSE:  12601725.7455
# Lasso R2: 0.865103711366
# ~~~ Ridge ~~~
# Ridge MSE:  12601714.4251
# Ridge R2: 0.865103832546

# %% [markdown]
# ### Cross Validating the Model
# It appears the model is consistent when cross validating throuhg 10 folds. Thanks again for this handy code!

# %%
kf = cross_validation.KFold(len(X), n_folds=10, shuffle=True)

mse_values = []
scores = []
n= 0
print "~~~~ CROSS VALIDATION each fold ~~~~"
for train_index, test_index in kf:
    lm = linear_model.LinearRegression().fit(X.iloc[train_index], y.iloc[train_index])
    mse_values.append(metrics.mean_squared_error(y.iloc[test_index], lm.predict(X.iloc[test_index])))
    scores.append(lm.score(X, y))
    print 'Model', n
    print 'MSE:', mse_values[n-1]
    print 'R2:', scores[n-1]


print "~~~~ SUMMARY OF CROSS VALIDATION ~~~~"
print 'Mean of MSE for all folds:', np.mean(mse_values)
print 'Mean of R2 for all folds:', np.mean(scores)
# Out:
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 0
# MSE: 11974921.0668
# R2: 0.865100501779
# Model 0
# MSE: 12838294.056
# R2: 0.865093432554
# Model 0
# MSE: 13267521.1149
# R2: 0.865099142781
# Model 0
# MSE: 11004483.8073
# R2: 0.865101060834
# Model 0
# MSE: 12491852.2364
# R2: 0.865089523359
# Model 0
# MSE: 13754723.7185
# R2: 0.865084716057
# Model 0
# MSE: 13420997.8867
# R2: 0.865096712552
# Model 0
# MSE: 13211125.8776
# R2: 0.865099587003
# Model 0
# MSE: 12699231.7514
# R2: 0.865095546605
# Model 0
# MSE: 11498708.5806
# R2: 0.865097433516
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 12616186.0096
# Mean of R2 for all folds: 0.865095765704

# %% [markdown]
# ### Predicting Change for a Sample Set.
#
# ##### Permutations of the following were set up in a dataframe.
# - 2010 Median Income at 10k, 15k, 20k, 30k, and 50k
#
# - Additional Low-Income Units in the census tract (50, 100,200,400)
#
# - Target Population (1/0)
#
# - Difficult Development Area (1/0)
#
# This dummy model makes sense in terms of a realistic potential development. Anything above a 400 unit building is very rare.

# %%
df_predict = pd.read_csv("PredictiveSet.csv")
X = df_predict[['Income','Number of Units','TargetPop','DDA']]
df_predict['Prediction'] = lm.predict(X)
df_predict['Change'] = df_predict['Prediction'] - df_predict['Income']

df_predict.to_excel("Prediction.xlsx")

print df_predict.head(4)
sns.lmplot('Income', 'Change', data=df_predict, fit_reg=False, hue='Number of Units' )

plt.ylabel('Income Change 2010-2014')
plt.savefig('C:\Users\Dave\Documents\GitHub\LIHTC-Project-Distribution\Pictures\DummySet.png')
# Out:
#    Income  Number of Units  TargetPop  DDA    Prediction       Change
# 0   10000               50          0    0  11000.986516  1000.986516
# 1   10000              100          0    0  10915.573833   915.573833
# 2   10000              200          0    0  10744.748466   744.748466
# 3   10000              400          0    0  10403.097733   403.097733

# %% [markdown]
# ### Prediction model by State!
# - The model trains through each state and creates a lmplot with number of Low-Income units against Median Household income. The ouputs a seperate xlsx file with the same dummy dataset as above, for each state. Works super fast and hones down the model at a more local level. Remember: the states control the placement of these properties and it makes sense to assess.

# %%
#create linear regression by state. start by getting a list of states from the column of Project States

statelist = df_tiny.PROJ_ST_x.unique()
print statelist
print len(statelist)

for state in statelist:
    print "~~~~~~RUNNING FOR " + str(state) + " ~~~~~~"
    df_state = df[(df.PROJ_ST_x == state)]
    lm  = sns.lmplot(x="LI_UNITS_x", y="MHI_2014_x", order=1, data=df_state, hue='TargetPop_1')
    axes = lm.axes
    #axes[0,0].set_ylim(-0.75,.6)
    #axes[0,0].set_xlim(0,1000)
    sns.plt.title(state)
    lm.savefig('pictures/'+state + '.png')
    
    X = df_state[['MHI_2010_x','LI_UNITS_x','TargetPop_1','DDA_1']]



    y = df_state['MHI_2014_x']
    
    
    lm = linear_model.LinearRegression()
    lm.fit(X, y)
    print lm.get_params
    print lm.coef_
    print 'R-squared', lm.score(X,y)
    print 'MSE', metrics.mean_squared_error(y, lm.predict(X))
    #print lm.predict(np.array([100,0,0,1])) 
    
    df_predict = pd.read_csv("PredictiveSet.csv")
    X = df_predict[['Income','Number of Units','TargetPop','DDA']]
    df_predict['Prediction'] = lm.predict(X)
    df_predict['Change'] = df_predict['Prediction'] - df_predict['Income']

    df_predict.to_excel('State Prediction/Prediction_' + state + '.xlsx')
# Out:
# ['CA' 'DE' 'CO' 'DC' 'FL' 'CT' 'AR' 'AZ' 'GA' 'HI' 'IA' 'ID' 'IL' 'AK' 'AL'
#  'KY' 'MA' 'LA' 'MD' 'IN' 'ME' 'KS' 'MI' 'MN' 'MT' 'NC' 'MO' 'MS' 'NE' 'NJ'
#  'NH' 'ND' 'NV' 'NY' 'NM' 'OH' 'OR' 'PA' 'OK' 'RI' 'SC' 'SD' 'TN' 'WV' 'WI'
#  'WY' 'TX' 'VA' 'VT' 'UT' 'WA']
# 51
# ~~~~~~RUNNING FOR CA ~~~~~~
# <bound method LinearRegression.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)>
# [  0.97771108   0.12532526 -71.50624327 -36.23114634]
# R-squared 0.887520869504
# MSE 13833674.9984
# ~~~~~~RUNNING FOR DE ~~~~~~
# <bound method LinearRegression.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)>
# [  1.00287485e+00  -7.57230048e+00   5.78537660e+03   0.00000000e+00]
# R-squared 0.771579814488
# MSE 13163057.5435
# ~~~~~~RUNNING FOR CO ~~~~~~
# <bound method LinearRegression.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)>
# ...

# %% [markdown]
# ### Improving the model
#
# #### Data considerations
# - I wish I had a longer time series for the income data. A long-term approach would bode for a more realistic "impact" on the census tract's income. If I had my pick I could line up the dates where the project was placed in service with the income, but I only had income data from 2010 to 2014 and that was very limiting. Plus the fact that 2010 data is really 2006-2010 (5-year estimate).
#
# #### Time considerations
# - I would like to spend more time figuring out how to visualize the data.
#
# - I would like to spend more time mining the American Community Survey for more predictor variables, such as education attainment, metro area income, ect. There is a TON of variables in there but I was limited by time
#
# - I wish I had more time to create nicer visualizations.
#
# #### What did I learn?
# - How to run a simple API against a server.
#
# - How to run a linear regression and loop it through different scenarios (in my case, states).
#
# - Running a cross validation.
#
# - Learning that predicting a % change is impossible. Predicting the actual future income yield a meaningful result.
#
# - Realizing how many times I needed to revisit my original question. What exactly am I predicting? I must have thought about that a thousand times!
